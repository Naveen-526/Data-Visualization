# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 881          882         0       3  ...   7.8958   NaN         S
# 882          883         0       3  ...  10.5167   NaN         S
# 883          884         0       2  ...  10.5000   NaN         S
# 884          885         0       3  ...   7.0500   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [10 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head(10).isnull()
# Out:
#    PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0        False     False   False  False  ...   False  False   True     False
# 1        False     False   False  False  ...   False  False  False     False
# 2        False     False   False  False  ...   False  False   True     False
# 3        False     False   False  False  ...   False  False  False     False
# 4        False     False   False  False  ...   False  False   True     False
# 5        False     False   False  False  ...   False  False   True     False
# 6        False     False   False  False  ...   False  False  False     False
# 7        False     False   False  False  ...   False  False   True     False
# 8        False     False   False  False  ...   False  False   True     False
# 9        False     False   False  False  ...   False  False   True     False
#
# [10 rows x 12 columns]

# %%
df.dtypes  # Age = float       }     ---  having  Nan values
           # cabin = object    }     ---   Nan values
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Age'].unique().shape
# Out:
# (89,)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (183, 12)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
# 5            6         0       3  ...   8.4583   NaN         Q
# 6            7         0       1  ...  51.8625   E46         S
# 7            8         0       3  ...  21.0750   NaN         S
# 8            9         1       3  ...  11.1333   NaN         S
# 9           10         1       2  ...  30.0708   NaN         C
#
# [10 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (183, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000  0.148495 -0.089136  ... -0.083488 -0.051454  0.029740
# Survived        0.148495  1.000000 -0.034542  ...  0.106346  0.023582  0.134241
# Pclass         -0.089136 -0.034542  1.000000  ... -0.103592  0.047496 -0.315235
# Age             0.030933 -0.254085 -0.306514  ... -0.156162 -0.271271 -0.092424
# SibSp          -0.083488  0.106346 -0.103592  ...  1.000000  0.255346  0.286433
# Parch          -0.051454  0.023582  0.047496  ...  0.255346  1.000000  0.389740
# Fare            0.029740  0.134241 -0.315235  ...  0.286433  0.389740  1.000000
#
# [7 rows x 7 columns]

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(df)

# %%
sns.displot(data = df, x = 'Pclass',y = 'SibSp' )

# %%
sns.jointplot(x = 'Age',y = 'Pclass',data = df)

# %%
sns.jointplot(x = 'Age',y = 'Pclass',data = df,kind = 'hex',color = 'r')

# %%
sns.pairplot(df, hue = 'Survived')

# %%
sns.countplot(x = 'Pclass',data = df, hue = 'SibSp',palette = 'icefire')

# %%
sns.countplot(y = 'Pclass',data = df, hue = 'SibSp',palette = 'magma')

# %%
sns.countplot(x = 'Pclass',data = df, hue = 'SibSp',palette = 'hot_r')

# %%
sns.pointplot(x = 'Age',y = 'Gender',data = df)

# %%
sns.pointplot(x = 'Survived',y = 'Name',data = df)

# %%
sns.distplot(df['Survived'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(df['Survived'])

# %%
sns.countplot('Survived',data = df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(x = 'Fare',data = df)

# %%
sns.kdeplot(x = 'Survived',y = "Age",data = df)

# %%
sns.lineplot(x = 'Age',y = 'Fare',data = df)
